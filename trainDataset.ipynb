# %% [markdown]
# ## Reading CSV file

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("dataset.csv", header=None)
df
# Out:
#            0         1             2         3         4         5         6
# 0    0.371497  0.770230 -5.436919e-07  0.423772  0.750980 -0.011408  0.444693  \
# 1    0.374563  0.750391 -8.094292e-08  0.422857  0.713394 -0.001243  0.435118
# 2    0.006824  0.630612  4.259505e-07  0.044556  0.562804 -0.000310  0.099534
# 3   -0.027311  0.627443 -3.604709e-07  0.010075  0.566962  0.007843  0.069718
# 4   -0.011365  0.722017 -3.916727e-07 -0.001835  0.648950 -0.003489  0.026142
# ..        ...       ...           ...       ...       ...       ...       ...
# 714  0.301034  0.806786  4.997472e-07  0.364163  0.758228 -0.031647  0.409622
# 715  0.300351  0.807205  5.030851e-07  0.363886  0.759522 -0.031090  0.408468
# 716  0.301340  0.806074  3.636625e-07  0.361996  0.749682 -0.025230  0.402558
# 717  0.301410  0.803600  3.631128e-07  0.360480  0.743050 -0.022732  0.398225
# 718  0.298678  0.796924  4.474661e-07  0.360521  0.740526 -0.024497  0.399968
#
#            7         8         9   ...        54        55        56
# 0    0.698966 -0.014402  0.445824  ...  0.453204  0.637185 -0.026919  \
# 1    0.648857  0.001988  0.434803  ...  0.421937  0.597890 -0.008234
# 2    0.541379 -0.007963  0.148340  ...  0.181575  0.685638 -0.028548
# 3    0.541230  0.003206  0.118577  ...  0.137500  0.728646 -0.035867
# 4    0.567313 -0.009868  0.047479  ...  0.136349  0.587380 -0.042574
# ..        ...       ...       ...  ...       ...       ...       ...
# 714  0.686463 -0.045832  0.437477  ...  0.223743  0.540076 -0.058383
# 715  0.686943 -0.044953  0.436966  ...  0.222135  0.540277 -0.058690
# 716  0.668909 -0.034938  0.425797  ...  0.216839  0.543349 -0.054906
# 717  0.665313 -0.030673  0.417333  ...  0.210766  0.548897 -0.047207
# 718  0.665861 -0.031955  0.416613  ...  0.209054  0.544380 -0.041205
#
#            57        58        59        60        61        62    63
# 0    0.448251  0.669092 -0.026570  0.429668  0.679154 -0.024304  full
# 1    0.421375  0.621952 -0.004683  0.408823  0.633244 -0.000900  full
# 2    0.200178  0.664163 -0.011774  0.209391  0.652927  0.002673  full
# 3    0.122605  0.724434 -0.017841  0.100223  0.715967 -0.005547  full
# 4    0.102844  0.565402 -0.035379  0.074837  0.571607 -0.025722  full
# ..        ...       ...       ...       ...       ...       ...   ...
# 714  0.213611  0.494120 -0.068399  0.204770  0.449599 -0.074691  stop
# 715  0.212567  0.494243 -0.068604  0.204195  0.450004 -0.074907  stop
# 716  0.207072  0.495539 -0.065309  0.198820  0.449635 -0.072403  stop
# 717  0.203354  0.502648 -0.056164  0.199809  0.456820 -0.062015  stop
# 718  0.203397  0.497998 -0.051823  0.202704  0.450849 -0.058541  stop
#
# [719 rows x 64 columns]

# %%
df = df.rename(columns={63: 'label'})
df
# Out:
#             0         1             2         3         4         5         6
# 0    0.371497  0.770230 -5.436919e-07  0.423772  0.750980 -0.011408  0.444693  \
# 1    0.374563  0.750391 -8.094292e-08  0.422857  0.713394 -0.001243  0.435118
# 2    0.006824  0.630612  4.259505e-07  0.044556  0.562804 -0.000310  0.099534
# 3   -0.027311  0.627443 -3.604709e-07  0.010075  0.566962  0.007843  0.069718
# 4   -0.011365  0.722017 -3.916727e-07 -0.001835  0.648950 -0.003489  0.026142
# ..        ...       ...           ...       ...       ...       ...       ...
# 714  0.301034  0.806786  4.997472e-07  0.364163  0.758228 -0.031647  0.409622
# 715  0.300351  0.807205  5.030851e-07  0.363886  0.759522 -0.031090  0.408468
# 716  0.301340  0.806074  3.636625e-07  0.361996  0.749682 -0.025230  0.402558
# 717  0.301410  0.803600  3.631128e-07  0.360480  0.743050 -0.022732  0.398225
# 718  0.298678  0.796924  4.474661e-07  0.360521  0.740526 -0.024497  0.399968
#
#             7         8         9  ...        54        55        56
# 0    0.698966 -0.014402  0.445824  ...  0.453204  0.637185 -0.026919  \
# 1    0.648857  0.001988  0.434803  ...  0.421937  0.597890 -0.008234
# 2    0.541379 -0.007963  0.148340  ...  0.181575  0.685638 -0.028548
# 3    0.541230  0.003206  0.118577  ...  0.137500  0.728646 -0.035867
# 4    0.567313 -0.009868  0.047479  ...  0.136349  0.587380 -0.042574
# ..        ...       ...       ...  ...       ...       ...       ...
# 714  0.686463 -0.045832  0.437477  ...  0.223743  0.540076 -0.058383
# 715  0.686943 -0.044953  0.436966  ...  0.222135  0.540277 -0.058690
# 716  0.668909 -0.034938  0.425797  ...  0.216839  0.543349 -0.054906
# 717  0.665313 -0.030673  0.417333  ...  0.210766  0.548897 -0.047207
# 718  0.665861 -0.031955  0.416613  ...  0.209054  0.544380 -0.041205
#
#            57        58        59        60        61        62  label
# 0    0.448251  0.669092 -0.026570  0.429668  0.679154 -0.024304   full
# 1    0.421375  0.621952 -0.004683  0.408823  0.633244 -0.000900   full
# 2    0.200178  0.664163 -0.011774  0.209391  0.652927  0.002673   full
# 3    0.122605  0.724434 -0.017841  0.100223  0.715967 -0.005547   full
# 4    0.102844  0.565402 -0.035379  0.074837  0.571607 -0.025722   full
# ..        ...       ...       ...       ...       ...       ...    ...
# 714  0.213611  0.494120 -0.068399  0.204770  0.449599 -0.074691   stop
# 715  0.212567  0.494243 -0.068604  0.204195  0.450004 -0.074907   stop
# 716  0.207072  0.495539 -0.065309  0.198820  0.449635 -0.072403   stop
# 717  0.203354  0.502648 -0.056164  0.199809  0.456820 -0.062015   stop
# 718  0.203397  0.497998 -0.051823  0.202704  0.450849 -0.058541   stop
#
# [719 rows x 64 columns]

# %% [markdown]
# ### Splitting Data into Input and Ouput

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

print(x.shape)
print(y.shape)
# Out:
# (719, 63)
# (719,)

# %% [markdown]
# ### Splitting data into train and test data

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %% [markdown]
# ### Training Different Models

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC
svm = SVC(probability=True)

# %%
svm.fit(x_train,y_train)
svm.score(x_test,y_test)
# Out:
# 1.0

# %%
import pickle

with open('svm.pkl','wb') as f:
    pickle.dump(svm,f)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()

# %%
log.fit(x_train,y_train)
log.score(x_test,y_test)
# Out:
# c:\Users\ravin\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 1.0

# %%
import pickle

with open('log.pkl','wb') as f:
    pickle.dump(log,f)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
tree.fit(x_train,y_train)
tree.score(x_test,y_test)
# Out:
# 1.0

# %%
import pickle

with open('tree.pkl','wb') as f:
    pickle.dump(tree,f)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
# Out:
# 1.0

# %%
import pickle

with open('knn.pkl','wb') as f:
    pickle.dump(knn,f)

# %% [markdown]
# ### Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(x_train,y_train)
nb.score(x_test,y_test)
# Out:
# 0.99375
